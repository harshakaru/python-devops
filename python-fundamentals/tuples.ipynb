# %% [markdown]
# # Tuples (`tuple`)
#
# Tuples are ordered, immutable sequences defined with parentheses `()`. Once created, their contents cannot be changed.

# %% [markdown]
# ## Characteristics and Use Cases
# - Ordered: items maintain position
# - Immutable: cannot add, remove, or change after creation
# - Useful for fixed records like coordinates, version numbers, or as dictionary keys

# %%
host_port = ("192.168.2.1", 3000)
red_rgb = (255, 0, 0)
tupple_single_value = ("only-value",) # To create a single-item tuple, add a trailling comma
print(type(host_port))
print(type(tupple_single_value))

tupple_single_value_error = ("only-value")
print(type(tupple_single_value_error))

print(f"Host:{host_port[0]}")
print(red_rgb[-2:])
print(type(red_rgb[-2:]))

# host_port[0] = "127.0.0.1" # TypeError: 'tuple' object does not support item assignment
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'str'>
# Host:192.168.2.1
# (0, 0)
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 print(red_rgb[-2:])
#      12 print(type(red_rgb[-2:]))
# ---> 14 host_port[0] = "127.0.0.1"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Hands-on Exercise
# 1. Create a tuple `service_endpoint` with hostname and port values.
# 2. Print the hostname and port.
# 3. Attempt to modify an element (commented out to avoid error).

# %%
# Create a tuple
service_endpoint = ("Enoviev-ftp" , 21)

# Print
print(type(service_endpoint))
print(service_endpoint)
print(f"Hostname: {service_endpoint[0]}")
print(f"Port: {service_endpoint[1]}")

# Try to modify but it impossible 
#service_endpoint[1] = 22 #TypeError: 'tuple' object does not support item assignment
# Out:
# <class 'tuple'>
# ('Enoviev-ftp', 21)
# Hostname: Enoviev-ftp
# Port: 21
